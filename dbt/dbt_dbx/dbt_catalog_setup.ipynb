# %%
# %sql
-- Show available external locations
SHOW EXTERNAL LOCATIONS;
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>name</th><th>url</th><th>comment</th></tr></thead><tbody><tr><td>dbxdl-dataeng-storage-account-read-only</td><td>abfss://dataeng@dbxdl.dfs.core.windows.net/lineitems</td><td>null</td></tr><tr><td>dbxdl-delta-storage-account</td><td>abfss://delta@dbxdl.dfs.core.windows.net/</td><td>null</td></tr><tr><td>dbxdl-demo-storage-account-read-only</td><td>abfss://demo@dbxdl.dfs.core.windows.net/</td><td>null</td></tr><tr><td>dbxdl-warehouse-storage-account-read-only</td><td>abfss://warehouse@dbxdl.dfs.core.windows.net/</td><td>null</td></tr><tr><td>metastore_root_location</td><td>abfss://metastore@dbxmeta.dfs.core.windows.net/unitycatalog</td><td>Auto-created external location which provides access to the nominated metastore-level storage account for the metastore. Changing the URL on this external location will not update the metastore-level storage, and could break access. You can update the credential on this external location if desired.</td></tr></tbody></table></div>

# %%
# %sql
-- Show existing catalogs
SHOW CATALOGS;
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>catalog</th></tr></thead><tbody><tr><td>04_ai_semantics</td></tr><tr><td>04_concurrency</td></tr><tr><td>__databricks_internal</td></tr><tr><td>hive_metastore</td></tr><tr><td>lakebase-test</td></tr><tr><td>samples</td></tr><tr><td>system</td></tr></tbody></table></div>

# %%
# %sql
-- Create the catalog for concurrency testing
-- DROP CATALOG IF EXISTS 02_de_dbt CASCADE;
-- CREATE CATALOG IF NOT EXISTS 02_de_dbt;

# %%
# %sql
-- Set the catalog and schema context
USE CATALOG 02_de_dbt;
USE SCHEMA default;
